# %% [markdown]
# **Exercício 1 - Aquecimento de Python para Ciência de Dados**

# %% [markdown]
# 1. Imprima "Hello, World!" no console.

# %%
print ("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# 2. Crie uma variável x com valor 10 e imprima seu valor.

# %%
x = 10
print (x)
# Out:
# 10

# %% [markdown]
# 3. Some dois números e exiba o resultado.

# %%
x =  10
y = 15

print(x + y)
# Out:
# 25

# %% [markdown]
# 4. Verifique se um número é par ou ímpar.

# %%
if x % 2 == 0 : print (f"{x} é par.")
else: print(f"{x} é ímpar.")
# Out:
# 10 é par.

# %% [markdown]
# 5. Crie uma função que receba dois números e retorne a soma deles.

# %%
def soma(a, b):
 return a + b
resultado = soma(4, 7)
print(f"O resultado da soma é: {resultado}")
# Out:
# O resultado da soma é: 11

# %% [markdown]
# 6. Crie uma lista com os números de 1 a 5 e imprima-a.

# %%
lista = [ 1, 2, 3, 4, 5 ]
print(lista)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 7. Adicione o número 6 à lista criada na questão anterior.

# %%
lista.append(6)
print(lista)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 8. Remova o número 3 da lista.

# %%
lista.remove(3)
print(lista)
# Out:
# [1, 2, 4, 5, 6]

# %% [markdown]
# 9. Acesse o terceiro elemento da lista.

# %%
terceiroItem = lista[2]
print(terceiroItem)
# Out:
# 4

# %% [markdown]
# 10. Imprima o tamanho da lista.

# %%
tamanho =len(lista)
print(f"O tamanho da lista é: {tamanho}")
# Out:
# O tamanho da lista é: 5

# %% [markdown]
# 11. Crie um dicionário com informações de um carro (marca, modelo, ano).

# %%
carro = {
          "marca": "Fiat",
          "ano": "2015",
          "modelo": "Uno"
        }
print(carro)
# Out:
# {'marca': 'Fiat', 'ano': '2015', 'modelo': 'Uno'}

# %% [markdown]
# 12. Acesse o valor associado à chave "marca" no dicionário.

# %%
marca = carro["marca"]
print(marca)
# Out:
# Fiat

# %% [markdown]
# 13. Adicione uma nova chave "cor" com valor "preto" ao dicionário.

# %%
carro["cor"] = "vermelho"
print(carro)
# Out:
# {'marca': 'Fiat', 'ano': '2015', 'modelo': 'Uno', 'cor': 'vermelho'}

# %% [markdown]
# 14. Verifique se a chave "modelo" existe no dicionário.

# %%
if "modelo" in carro:
    print("A chave 'modelo' existe no dicionário ")
else:
    print("A chave 'modelo' não existe no dicionário ")
# Out:
# A chave 'modelo' existe no dicionário

# %% [markdown]
# 15. Itere sobre as chaves do dicionário e imprima cada uma delas.

# %%
for chave in carro:
    print(chave)
# Out:
# marca
# ano
# modelo
# cor

# %% [markdown]
# 15. Itere sobre as chaves do dicionário e imprima cada uma delas.

# %% [markdown]
# 17. Crie uma função que receba uma lista e retorne a soma dos elementos.

# %%
def soma_elementos(lista):
    return sum(lista)
numeros = [1, 2, 3, 4, 5]
resultado = soma_elementos(numeros)
print(f"A soma dos elementos é: {resultado}")
# Out:
# A soma dos elementos é: 15

# %% [markdown]
# 18. Crie uma função que receba um dicionário e retorne todas as suas chaves.

# %%
def obter_chaves(dicionario):
    return list(dicionario.keys())
    carro = {
    "modelo": "Uno",
    "marca": "Fiat",
    "ano": 2015,
    "cor": "vermelho"
}

chaves_do_carro = obter_chaves(carro)
print(f"As chaves do dicionário carro são: {chaves_do_carro}")
# Out:
# As chaves do dicionário carro são: ['marca', 'ano', 'modelo', 'cor']

# %% [markdown]
# 19. Crie uma função que receba um dicionário e imprima chave e valor em linhas separadas.

# %%
def imprimir_chaves_valores(dicionario):
    for chave, valor in dicionario.items():
        print(f"Chave: {chave}, Valor: {valor}")
    carro = {
    "modelo": "Uno",
    "marca": "Fiat",
    "ano": 2015,
    "cor": "vermelho"
}

imprimir_chaves_valores(carro)
# Out:
# Chave: marca, Valor: Fiat
# Chave: ano, Valor: 2015
# Chave: modelo, Valor: Uno
# Chave: cor, Valor: vermelho

# %% [markdown]
# 20. Crie uma classe chamada Pessoa com atributos nome e idade, e um método que imprima esses dados.

# %%
class Pessoa:
    def __init__(self, nome, idade):
        self.nome = nome
        self.idade = idade

    def imprimir_dados(self):
        print(f"Nome: {self.nome}, Idade: {self.idade}")
pessoa1 = Pessoa("Aline Beatriz", 21)
pessoa1.imprimir_dados()
# Out:
# Nome: Aline Beatriz, Idade: 21
